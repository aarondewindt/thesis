# %% [markdown]
# # Initialize learning environment

# %%
import ray
from cw.vdom import hyr

# %%
hyr(ray.init(dashboard_host="0.0.0.0"))
# Out:
# 2021-06-27 22:43:23,998	INFO services.py:1272 -- View the Ray dashboard at http://10.10.1.2:8265
# dict[9]:
#
# node_ip_addressstr[9]:
#
# 10.10.1.2
#
# raylet_ip_addressstr[9]:
#
# 10.10.1.2
#
# redis_addressstr[14]:
#
# 10.10.1.2:6379
#
# object_store_addressstr[67]:
#
# /tmp/ray/session_2021-06-27_22-43-22_392360_52/sockets/plasma_store
#
# raylet_socket_namestr[61]:
#
# /tmp/ray/session_2021-06-27_22-43-22_392360_52/sockets/raylet
#
# webui_urlstr[14]:
#
# 10.10.1.2:8265
#
# session_dirstr[46]:
#
# /tmp/ray/session_2021-06-27_22-43-22_392360_52
#
# metrics_export_portint:
#
# 59946
#
# node_idstr[56]:
#
# f6a6b5e91b73e917bc5bd0bd78e83be3134657d01336b8a1a9d9e9ed

# %%
ray.shutdown()

# %%
# !tensorboard --logdir=./results --port=8270 --host=0.0.0.0
# Out:
# TensorBoard 2.4.1 at http://0.0.0.0:8270/ (Press CTRL+C to quit)
