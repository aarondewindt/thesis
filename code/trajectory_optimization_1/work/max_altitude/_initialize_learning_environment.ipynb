# %% [markdown]
# # Initialize learning environment

# %%
import ray
from cw.vdom import hyr

# %%
hyr(ray.init(dashboard_host="0.0.0.0"))
# Out:
# 2021-06-25 00:53:44,697	INFO services.py:1272 -- View the Ray dashboard at http://10.10.1.2:8265
# dict[9]:
#
# node_ip_addressstr[9]:
#
# 10.10.1.2
#
# raylet_ip_addressstr[9]:
#
# 10.10.1.2
#
# redis_addressstr[14]:
#
# 10.10.1.2:6379
#
# object_store_addressstr[67]:
#
# /tmp/ray/session_2021-06-25_00-53-43_212314_84/sockets/plasma_store
#
# raylet_socket_namestr[61]:
#
# /tmp/ray/session_2021-06-25_00-53-43_212314_84/sockets/raylet
#
# webui_urlstr[14]:
#
# 10.10.1.2:8265
#
# session_dirstr[46]:
#
# /tmp/ray/session_2021-06-25_00-53-43_212314_84
#
# metrics_export_portint:
#
# 48431
#
# node_idstr[56]:
#
# 246474c16378c32c3659e1e06e8cbcfd325fcef14742b45fc75fc059

# %%
ray.shutdown()

# %%
# !tensorboard --logdir=./results --port=8270 --host=0.0.0.0
# Out:
# TensorBoard 2.4.1 at http://0.0.0.0:8270/ (Press CTRL+C to quit)
