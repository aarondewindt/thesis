# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
from math import radians

import matplotlib.pyplot as plt
from scipy.optimize import minimize

from environment import LauncherV1Orbital, Stage
from case_runner import CaseRunner
from pso_optimizer import PSOOptimizer
from plotting import Plotter

# %%
env = LauncherV1Orbital({
    "dt": 0.05,
    # "theta_e_random_window": radians(30),
    # "stages": (
    #     Stage( 
    #         dry_mass=1,
    #         propellant_mass=0.95,
    #         specific_impulse=400,
    #         thrust=4*1.7),
    # ),
    # "initial_theta_e": radians(15),
    # "autopilot_mode": AP_FLIGHT_PATH_CONTROL,
    # "initial_kepler": {
    #     "a": moon_radius + 100e3,
    #     "e": .0,
    #     "true_anomaly": 0.,
    # }
})
env
# Out:
# /home/adewindt/repos/thesis/code/trajectory_optimization_1/traj1/environments/launcher_v1/simulation.py:121: NumbaWarning: Cannot cache compiled function "new_simulation" as it uses dynamic globals (such as ctypes pointers and large global arrays)
#   @nb.jit(nopython=True, cache=True)
# <div Class="cw_vdom_hyr cw_vdom_hyr_item"><style>.cw_vdom_hyr {
#     font-family: monospace;
# }
#
# .cw_vdom_hyr_item > input {
#     display: none;
# }
#
# .cw_vdom_hyr_item > label {
#     color: var(--jp-accent-color1);
#     font-weight: bold;
# }
#
# .cw_vdom_hyr_item > label::before {
#     content: "\00a0";
# }
#
# .cw_vdom_hyr_item > label::after {
#     content: ": ";
# }
#
# .cw_vdom_hyr_item > div {
#     display: inline-block;
# }
#
# .cw_vdom_hyr_item > input + label {
#     cursor: pointer;
# }
#
# .cw_vdom_hyr_item > input + label::before {
#     content: "+";
# }
#
# .cw_vdom_hyr_item > input:checked + label::before {
#     content: "-";
# }
#
# .cw_vdom_hyr_item > input ~ div {
#     display: none;
#     padding-left: 20px;
# }
#
# .cw_vdom_hyr_item > input:checked ~ div {
#     display: block;
# }
#
# .cw_vdom_hyr_type {
#     color: var(--jp-ui-font-color3);
#     font-size: var(--jp-ui-font-size0);
# }
# </style><input type="checkbox" id="W8EN5JTJHX" checked></input><label For="W8EN5JTJHX"></label><span Class="cw_vdom_hyr_type">dict[3]:</span><div><div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="WV3M7S9PFB" ></input><label For="WV3M7S9PFB">config</label><span Class="cw_vdom_hyr_type">dict[18]:</span><div><div><div Class="cw_vdom_hyr_item"><label For="5DTRZRM8B0">dt</label><span Class="cw_vdom_hyr_type">float:</span><div><span>0.05</span></div></div><div Class="cw_vdom_hyr_item"><label For="NFLFVT6V41">surface_diameter</label><span Class="cw_vdom_hyr_type">float:</span><div><span>1737400.0</span></div></div><div Class="cw_vdom_hyr_item"><label For="8HMGV8LINB">mu</label><span Class="cw_vdom_hyr_type">float:</span><div><span>4904869500000.0</span></div></div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="64MIEODZX1" ></input><label For="64MIEODZX1">stages</label><span Class="cw_vdom_hyr_type">tuple[1]:</span><div><div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="2NYYJGGVXL" ></input><label For="2NYYJGGVXL">[0]</label><span Class="cw_vdom_hyr_type">traj1.environments.launcher_v1.launcher_v1.Stage:</span><div><div><div Class="cw_vdom_hyr cw_vdom_hyr_item"><style>.cw_vdom_hyr {
#     font-family: monospace;
# }
#
# .cw_vdom_hyr_item > input {
#     display: none;
# }
#
# .cw_vdom_hyr_item > label {
#     color: var(--jp-accent-color1);
#     font-weight: bold;
# }
#
# .cw_vdom_hyr_item > label::before {
#     content: "\00a0";
# }
#
# .cw_vdom_hyr_item > label::after {
#     content: ": ";
# }
#
# .cw_vdom_hyr_item > div {
#     display: inline-block;
# }
#
# .cw_vdom_hyr_item > input + label {
#     cursor: pointer;
# }
#
# .cw_vdom_hyr_item > input + label::before {
#     content: "+";
# }
#
# .cw_vdom_hyr_item > input:checked + label::before {
#     content: "-";
# }
#
# .cw_vdom_hyr_item > input ~ div {
#     display: none;
#     padding-left: 20px;
# }
#
# .cw_vdom_hyr_item > input:checked ~ div {
#     display: block;
# }
#
# .cw_vdom_hyr_type {
#     color: var(--jp-ui-font-color3);
#     font-size: var(--jp-ui-font-size0);
# }
# </style><input type="checkbox" id="JQU2SPNNBP" checked></input><label For="JQU2SPNNBP">Stage</label><span Class="cw_vdom_hyr_type">traj1.environments.launcher_v1.launcher_v1.Stage:</span><div><div><div Class="cw_vdom_hyr_item"><label For="5NRAF5F8IL">dry_mass</label><span Class="cw_vdom_hyr_type">int:</span><div><span>2150</span></div></div><div Class="cw_vdom_hyr_item"><label For="WT1P03DWC3">propellant_mass</label><span Class="cw_vdom_hyr_type">int:</span><div><span>2353</span></div></div><div Class="cw_vdom_hyr_item"><label For="ER7CERCR6T">specific_impulse</label><span Class="cw_vdom_hyr_type">int:</span><div><span>311</span></div></div><div Class="cw_vdom_hyr_item"><label For="T7DH11F5L7">thrust</label><span Class="cw_vdom_hyr_type">int:</span><div><span>16000</span></div></div><div Class="cw_vdom_hyr_item"><label For="YB2QR4FFN8">n_ignitions</label><span Class="cw_vdom_hyr_type">int:</span><div><span>1</span></div></div><div Class="cw_vdom_hyr_item"><label For="SCLKMFHTG4">burn_time</label><span Class="cw_vdom_hyr_type">float:</span><div><span>448.67445187500005</span></div></div></div></div></div></div></div></div></div></div></div><div Class="cw_vdom_hyr_item"><label For="J82MGQW12S">initial_altitude</label><span Class="cw_vdom_hyr_type">int:</span><div><span>1</span></div></div><div Class="cw_vdom_hyr_item"><label For="NJG6Y891GI">initial_theta_e</label><span Class="cw_vdom_hyr_type">float:</span><div><span>1.5707963267948966</span></div></div><div Class="cw_vdom_hyr_item"><label For="EYMKU7DFVD">initial_longitude</label><span Class="cw_vdom_hyr_type">float:</span><div><span>1.5707963267948966</span></div></div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="705NDDM384" ></input><label For="705NDDM384">initial_vie</label><span Class="cw_vdom_hyr_type">tuple[2]:</span><div><div><div Class="cw_vdom_hyr_item"><label For="RT6WL0YNQR">[0]</label><span Class="cw_vdom_hyr_type">float:</span><div><span>0.0</span></div></div><div Class="cw_vdom_hyr_item"><label For="QDZYWBNDJZ">[1]</label><span Class="cw_vdom_hyr_type">float:</span><div><span>0.0</span></div></div></div></div></div><div Class="cw_vdom_hyr_item"><label For="01NFGGVD9Z">initial_kepler</label><span Class="cw_vdom_hyr_type">NoneType:</span><div><span>None</span></div></div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="S5J7HOY1LE" ></input><label For="S5J7HOY1LE">gamma_controller_gains</label><span Class="cw_vdom_hyr_type">tuple[3]:</span><div><div><div Class="cw_vdom_hyr_item"><label For="2ULQR6ZK6V">[0]</label><span Class="cw_vdom_hyr_type">int:</span><div><span>4</span></div></div><div Class="cw_vdom_hyr_item"><label For="M0BRZAQECH">[1]</label><span Class="cw_vdom_hyr_type">int:</span><div><span>0</span></div></div><div Class="cw_vdom_hyr_item"><label For="UT6P5Y7K1A">[2]</label><span Class="cw_vdom_hyr_type">float:</span><div><span>0.2</span></div></div></div></div></div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="VUPHLP8ZDD" ></input><label For="VUPHLP8ZDD">theta_controller_gains</label><span Class="cw_vdom_hyr_type">tuple[3]:</span><div><div><div Class="cw_vdom_hyr_item"><label For="SLYWCV3AHQ">[0]</label><span Class="cw_vdom_hyr_type">int:</span><div><span>10</span></div></div><div Class="cw_vdom_hyr_item"><label For="9YVIJR4XT6">[1]</label><span Class="cw_vdom_hyr_type">int:</span><div><span>0</span></div></div><div Class="cw_vdom_hyr_item"><label For="MIXR6SQ9KN">[2]</label><span Class="cw_vdom_hyr_type">float:</span><div><span>0.0</span></div></div></div></div></div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="UB1BHNS9O9" ></input><label For="UB1BHNS9O9">controller_theta_dot_limits</label><span Class="cw_vdom_hyr_type">tuple[2]:</span><div><div><div Class="cw_vdom_hyr_item"><label For="2QZA3JHQXX">[0]</label><span Class="cw_vdom_hyr_type">int:</span><div><span>-1</span></div></div><div Class="cw_vdom_hyr_item"><label For="0Z9FMWW7UN">[1]</label><span Class="cw_vdom_hyr_type">int:</span><div><span>1</span></div ...

# %%
case_runner = CaseRunner(
    env=env,
    max_time=1000
)

# %%
optimizer = PSOOptimizer(case_runner)

# %%
optimizer.optimize(10)
# Out:
# 2022-07-08 14:07:49,564 - pyswarms.single.global_best - INFO - Optimize for 10 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best:   0%|                                                                                                                                         |0/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 optimizer.optimize(10)
#
# File ~/repos/thesis/code/trajectory_optimization_1/work/to_orbital/pso_optimizer.py:22, in PSOOptimizer.optimize(self, iters)
#      19     return costs
#      21 # Perform optimization
# ---> 22 return self.optimizer.optimize(cost_function, iters=iters)
#
# File ~/miniconda3/envs/traj1/lib/python3.9/site-packages/pyswarms/single/global_best.py:209, in GlobalBestPSO.optimize(self, objective_func, iters, n_processes, verbose, **kwargs)
#     205 ftol_history = deque(maxlen=self.ftol_iter)
#     206 for i in self.rep.pbar(iters, self.name) if verbose else range(iters):
#     207     # Compute cost for current position and personal best
#     208     # fmt: off
# --> 209     self.swarm.current_cost = compute_objective_function(self.swarm, objective_func, pool=pool, **kwargs)
#     210     self.swarm.pbest_pos, self.swarm.pbest_cost = compute_pbest(self.swarm)
#     211     # Set best_cost_yet_found for ftol
#
# File ~/miniconda3/envs/traj1/lib/python3.9/site-packages/pyswarms/backend/operators.py:239, in compute_objective_function(swarm, objective_func, pool, **kwargs)
#     214 """Evaluate particles using the objective function
#     215
#     216 This method evaluates each particle in the swarm according to the objective
#    (...)
#     236     Cost-matrix for the given swarm
#     237 """
#     238 if pool is None:
# --> 239     return objective_func(swarm.position, **kwargs)
#     240 else:
#     241     results = pool.map(
#     242         partial(objective_func, **kwargs),
#     243         np.array_split(swarm.position, pool._processes),
#     244     )
#
# File ~/repos/thesis/code/trajectory_optimization_1/work/to_orbital/pso_optimizer.py:18, in PSOOptimizer.optimize.<locals>.cost_function(swarm_positions)
#      16 costs = np.empty((swarm_positions.shape[0],))
#      17 for i, x in enumerate(swarm_positions):
# ---> 18     costs[i] = self.case_runner(x)
#      19 return costs
#
# File ~/repos/thesis/code/trajectory_optimization_1/work/to_orbital/case_runner.py:36, in CaseRunner.__call__(self, x)
#      33 times = (0, *x[3:n_checkpoints+1], self.max_time)
#      34 pitches = x[n_checkpoints+1:]
# ---> 36 result = self.run_case_interpolation(engine_timing, times, pitches)
#      38 final_h = result.env_h.values[-1]
#      39 final_eccentricity = result.env_eccentricity.values[-1]
#
# File ~/repos/thesis/code/trajectory_optimization_1/work/to_orbital/case_runner.py:46, in CaseRunner.run_case_interpolation(self, engine_timing, times, pitches)
#      45 def run_case_interpolation(self, engine_timing, times, pitches):
# ---> 46     pitch_interpolator = interp1d(times, pitches, fill_value="extrapolate")
#      48     observation = self.env.reset()
#      49     for i in range(int(self.max_time / self.env.sim.integrator.h)):
#
# File ~/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/interpolate/interpolate.py:436, in interp1d.__init__(self, x, y, kind, axis, copy, bounds_error, fill_value, assume_sorted)
#     432 def __init__(self, x, y, kind='linear', axis=-1,
#     433              copy=True, bounds_error=None, fill_value=np.nan,
#     434              assume_sorted=False):
#     435     """ Initialize a 1-D linear interpolation class."""
# --> 436     _Interpolator1D.__init__(self, x, y, axis=axis)
#     438     self.bounds_error = bounds_error  # used by fill_value setter
#     439     self.copy = copy
#
# File ~/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/interpolate/polyint.py:54, in _Interpolator1D.__init__(self, xi, yi, axis)
#      52 self.dtype = None
#      53 if yi is not None:
# ---> 54     self._set_yi(yi, xi=xi, axis=axis)
#
# File ~/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/interpolate/polyint.py:124, in _Interpolator1D._set_yi(self, yi, xi, axis)
#     122     shape = (1,)
#     123 if xi is not None and shape[axis] != len(xi):
# --> 124     raise ValueError("x and y arrays must be equal in length along "
#     125                      "interpolation axis.")
#     127 self._y_axis = (axis % yi.ndim)
#     128 self._y_extra_shape = yi.shape[:self._y_axis]+yi.shape[self._y_axis+1:]
#
# ValueError: x and y arrays must be equal in length along interpolation axis.
