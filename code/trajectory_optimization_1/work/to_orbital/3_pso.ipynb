# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
from math import radians
import pickle

import matplotlib.pyplot as plt
from scipy.optimize import minimize

from environment import LauncherV1Orbital, Stage
from case_runner import CaseRunner
from pso_optimizer import PSOOptimizer
from plotting import Plotter

# %%
env = LauncherV1Orbital({
    "dt": 0.05,
    # "theta_e_random_window": radians(30),
    # "stages": (
    #     Stage( 
    #         dry_mass=1,
    #         propellant_mass=0.95,
    #         specific_impulse=400,
    #         thrust=4*1.7),
    # ),
    # "initial_theta_e": radians(15),
    # "autopilot_mode": AP_FLIGHT_PATH_CONTROL,
    # "initial_kepler": {
    #     "a": moon_radius + 100e3,
    #     "e": .0,
    #     "true_anomaly": 0.,
    # }
})
env
# Out:
# /home/adewindt/repos/thesis/code/trajectory_optimization_1/traj1/environments/launcher_v1/simulation.py:121: NumbaWarning: Cannot cache compiled function "new_simulation" as it uses dynamic globals (such as ctypes pointers and large global arrays)
#   @nb.jit(nopython=True, cache=True)
# <div Class="cw_vdom_hyr cw_vdom_hyr_item"><style>.cw_vdom_hyr {
#     font-family: monospace;
# }
#
# .cw_vdom_hyr_item > input {
#     display: none;
# }
#
# .cw_vdom_hyr_item > label {
#     color: var(--jp-accent-color1);
#     font-weight: bold;
# }
#
# .cw_vdom_hyr_item > label::before {
#     content: "\00a0";
# }
#
# .cw_vdom_hyr_item > label::after {
#     content: ": ";
# }
#
# .cw_vdom_hyr_item > div {
#     display: inline-block;
# }
#
# .cw_vdom_hyr_item > input + label {
#     cursor: pointer;
# }
#
# .cw_vdom_hyr_item > input + label::before {
#     content: "+";
# }
#
# .cw_vdom_hyr_item > input:checked + label::before {
#     content: "-";
# }
#
# .cw_vdom_hyr_item > input ~ div {
#     display: none;
#     padding-left: 20px;
# }
#
# .cw_vdom_hyr_item > input:checked ~ div {
#     display: block;
# }
#
# .cw_vdom_hyr_type {
#     color: var(--jp-ui-font-color3);
#     font-size: var(--jp-ui-font-size0);
# }
# </style><input type="checkbox" id="YJQGZTA3MD" checked></input><label For="YJQGZTA3MD"></label><span Class="cw_vdom_hyr_type">dict[3]:</span><div><div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="XIPW9869VF" ></input><label For="XIPW9869VF">config</label><span Class="cw_vdom_hyr_type">dict[18]:</span><div><div><div Class="cw_vdom_hyr_item"><label For="RUP7C38RCI">dt</label><span Class="cw_vdom_hyr_type">float:</span><div><span>0.05</span></div></div><div Class="cw_vdom_hyr_item"><label For="GXDZFI7I6K">surface_diameter</label><span Class="cw_vdom_hyr_type">float:</span><div><span>1737400.0</span></div></div><div Class="cw_vdom_hyr_item"><label For="A2EH38REQU">mu</label><span Class="cw_vdom_hyr_type">float:</span><div><span>4904869500000.0</span></div></div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="694V0K1PW0" ></input><label For="694V0K1PW0">stages</label><span Class="cw_vdom_hyr_type">tuple[1]:</span><div><div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="W0NKN51BGV" ></input><label For="W0NKN51BGV">[0]</label><span Class="cw_vdom_hyr_type">traj1.environments.launcher_v1.launcher_v1.Stage:</span><div><div><div Class="cw_vdom_hyr cw_vdom_hyr_item"><style>.cw_vdom_hyr {
#     font-family: monospace;
# }
#
# .cw_vdom_hyr_item > input {
#     display: none;
# }
#
# .cw_vdom_hyr_item > label {
#     color: var(--jp-accent-color1);
#     font-weight: bold;
# }
#
# .cw_vdom_hyr_item > label::before {
#     content: "\00a0";
# }
#
# .cw_vdom_hyr_item > label::after {
#     content: ": ";
# }
#
# .cw_vdom_hyr_item > div {
#     display: inline-block;
# }
#
# .cw_vdom_hyr_item > input + label {
#     cursor: pointer;
# }
#
# .cw_vdom_hyr_item > input + label::before {
#     content: "+";
# }
#
# .cw_vdom_hyr_item > input:checked + label::before {
#     content: "-";
# }
#
# .cw_vdom_hyr_item > input ~ div {
#     display: none;
#     padding-left: 20px;
# }
#
# .cw_vdom_hyr_item > input:checked ~ div {
#     display: block;
# }
#
# .cw_vdom_hyr_type {
#     color: var(--jp-ui-font-color3);
#     font-size: var(--jp-ui-font-size0);
# }
# </style><input type="checkbox" id="IOERBK0DPQ" checked></input><label For="IOERBK0DPQ">Stage</label><span Class="cw_vdom_hyr_type">traj1.environments.launcher_v1.launcher_v1.Stage:</span><div><div><div Class="cw_vdom_hyr_item"><label For="Z9AXJK22IO">dry_mass</label><span Class="cw_vdom_hyr_type">int:</span><div><span>2150</span></div></div><div Class="cw_vdom_hyr_item"><label For="BJYMD7J28D">propellant_mass</label><span Class="cw_vdom_hyr_type">int:</span><div><span>2353</span></div></div><div Class="cw_vdom_hyr_item"><label For="T9NXVRCV3S">specific_impulse</label><span Class="cw_vdom_hyr_type">int:</span><div><span>311</span></div></div><div Class="cw_vdom_hyr_item"><label For="WIU0YPKB3N">thrust</label><span Class="cw_vdom_hyr_type">int:</span><div><span>16000</span></div></div><div Class="cw_vdom_hyr_item"><label For="8XJC6C68Y0">n_ignitions</label><span Class="cw_vdom_hyr_type">int:</span><div><span>1</span></div></div><div Class="cw_vdom_hyr_item"><label For="IWYNZY4UZB">burn_time</label><span Class="cw_vdom_hyr_type">float:</span><div><span>448.67445187500005</span></div></div></div></div></div></div></div></div></div></div></div><div Class="cw_vdom_hyr_item"><label For="81HIJOMIB8">initial_altitude</label><span Class="cw_vdom_hyr_type">int:</span><div><span>1</span></div></div><div Class="cw_vdom_hyr_item"><label For="2DIG9NOEZO">initial_theta_e</label><span Class="cw_vdom_hyr_type">float:</span><div><span>1.5707963267948966</span></div></div><div Class="cw_vdom_hyr_item"><label For="59139PV7UB">initial_longitude</label><span Class="cw_vdom_hyr_type">float:</span><div><span>1.5707963267948966</span></div></div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="ZYXA35DZN7" ></input><label For="ZYXA35DZN7">initial_vie</label><span Class="cw_vdom_hyr_type">tuple[2]:</span><div><div><div Class="cw_vdom_hyr_item"><label For="4V3EXZEZE4">[0]</label><span Class="cw_vdom_hyr_type">float:</span><div><span>0.0</span></div></div><div Class="cw_vdom_hyr_item"><label For="HIQNRNR9KO">[1]</label><span Class="cw_vdom_hyr_type">float:</span><div><span>0.0</span></div></div></div></div></div><div Class="cw_vdom_hyr_item"><label For="T820ZS6XVZ">initial_kepler</label><span Class="cw_vdom_hyr_type">NoneType:</span><div><span>None</span></div></div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="SIGHXYYTU7" ></input><label For="SIGHXYYTU7">gamma_controller_gains</label><span Class="cw_vdom_hyr_type">tuple[3]:</span><div><div><div Class="cw_vdom_hyr_item"><label For="TD23XMQ0DB">[0]</label><span Class="cw_vdom_hyr_type">int:</span><div><span>4</span></div></div><div Class="cw_vdom_hyr_item"><label For="FEMG3YWRC4">[1]</label><span Class="cw_vdom_hyr_type">int:</span><div><span>0</span></div></div><div Class="cw_vdom_hyr_item"><label For="KOD7ZHQRE8">[2]</label><span Class="cw_vdom_hyr_type">float:</span><div><span>0.2</span></div></div></div></div></div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="JFK9QRQV9L" ></input><label For="JFK9QRQV9L">theta_controller_gains</label><span Class="cw_vdom_hyr_type">tuple[3]:</span><div><div><div Class="cw_vdom_hyr_item"><label For="ZNO0P77KWH">[0]</label><span Class="cw_vdom_hyr_type">int:</span><div><span>10</span></div></div><div Class="cw_vdom_hyr_item"><label For="HZJNHM7WF1">[1]</label><span Class="cw_vdom_hyr_type">int:</span><div><span>0</span></div></div><div Class="cw_vdom_hyr_item"><label For="CCK8V5XB3Z">[2]</label><span Class="cw_vdom_hyr_type">float:</span><div><span>0.0</span></div></div></div></div></div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="KYC4JXYBOV" ></input><label For="KYC4JXYBOV">controller_theta_dot_limits</label><span Class="cw_vdom_hyr_type">tuple[2]:</span><div><div><div Class="cw_vdom_hyr_item"><label For="TWZB492LY5">[0]</label><span Class="cw_vdom_hyr_type">int:</span><div><span>-1</span></div></div><div Class="cw_vdom_hyr_item"><label For="5BUSNB5NRV">[1]</label><span Class="cw_vdom_hyr_type">int:</span><div><span>1</span></div ...

# %%
case_runner = CaseRunner(
    env=env,
    max_time=1000,
    n_checkpoints=4
)

# %%
case_runner.ndim
# Out:
# 9

# %%
pickled_cr = pickle.dumps(case_runner)

# %%
cr = pickle.loads(pickled_cr)

# %%
cr.ndim
# Out:
# 9

# %%
optimizer = PSOOptimizer(
    case_runner=case_runner,
    n_particles=100
)

# %%
optimizer.optimize(
    iters=10,
    n_processes=5
)
# Out:
# 2022-07-10 17:39:17,697 - pyswarms.single.global_best - INFO - Optimize for 10 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████|10/10, best_cost=0.144
# 2022-07-10 17:42:35,167 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.14350180077114638, best pos: [ 3.76823221e+02  2.74796296e+02  3.69703073e+02  6.85730048e+02
#   9.65621806e+02  4.69189614e-01 -4.94731205e-02 -3.34992689e-01
#  -1.44996166e-01]
# (0.14350180077114638,
#  array([ 3.76823221e+02,  2.74796296e+02,  3.69703073e+02,  6.85730048e+02,
#          9.65621806e+02,  4.69189614e-01, -4.94731205e-02, -3.34992689e-01,
#         -1.44996166e-01]))
