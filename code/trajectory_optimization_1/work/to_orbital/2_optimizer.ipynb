# %% [markdown]
# # Optimizer
#
# Basic optimizer

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
from math import radians

import matplotlib.pyplot as plt
from scipy.optimize import minimize

from environment import LauncherV1Orbital, Stage
from case_runner import CaseRunner
from plotting import Plotter

# %%
env = LauncherV1Orbital({
    "dt": 0.05,
    # "theta_e_random_window": radians(30),
    # "stages": (
    #     Stage( 
    #         dry_mass=1,
    #         propellant_mass=0.95,
    #         specific_impulse=400,
    #         thrust=4*1.7),
    # ),
    # "initial_theta_e": radians(15),
    # "autopilot_mode": AP_FLIGHT_PATH_CONTROL,
    # "initial_kepler": {
    #     "a": moon_radius + 100e3,
    #     "e": .0,
    #     "true_anomaly": 0.,
    # }
})
env
# Out:
# <div Class="cw_vdom_hyr cw_vdom_hyr_item"><style>.cw_vdom_hyr {
#     font-family: monospace;
# }
#
# .cw_vdom_hyr_item > input {
#     display: none;
# }
#
# .cw_vdom_hyr_item > label {
#     color: var(--jp-accent-color1);
#     font-weight: bold;
# }
#
# .cw_vdom_hyr_item > label::before {
#     content: "\00a0";
# }
#
# .cw_vdom_hyr_item > label::after {
#     content: ": ";
# }
#
# .cw_vdom_hyr_item > div {
#     display: inline-block;
# }
#
# .cw_vdom_hyr_item > input + label {
#     cursor: pointer;
# }
#
# .cw_vdom_hyr_item > input + label::before {
#     content: "+";
# }
#
# .cw_vdom_hyr_item > input:checked + label::before {
#     content: "-";
# }
#
# .cw_vdom_hyr_item > input ~ div {
#     display: none;
#     padding-left: 20px;
# }
#
# .cw_vdom_hyr_item > input:checked ~ div {
#     display: block;
# }
#
# .cw_vdom_hyr_type {
#     color: var(--jp-ui-font-color3);
#     font-size: var(--jp-ui-font-size0);
# }
# </style><input type="checkbox" id="PFX99DDOHL" checked></input><label For="PFX99DDOHL"></label><span Class="cw_vdom_hyr_type">dict[3]:</span><div><div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="CG86RH7KDJ" ></input><label For="CG86RH7KDJ">config</label><span Class="cw_vdom_hyr_type">dict[18]:</span><div><div><div Class="cw_vdom_hyr_item"><label For="5PI1EP6CXL">dt</label><span Class="cw_vdom_hyr_type">float:</span><div><span>0.05</span></div></div><div Class="cw_vdom_hyr_item"><label For="67AYX63MLI">surface_diameter</label><span Class="cw_vdom_hyr_type">float:</span><div><span>1737400.0</span></div></div><div Class="cw_vdom_hyr_item"><label For="73XJ0N2Y5G">mu</label><span Class="cw_vdom_hyr_type">float:</span><div><span>4904869500000.0</span></div></div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="TARHY5AK0N" ></input><label For="TARHY5AK0N">stages</label><span Class="cw_vdom_hyr_type">tuple[1]:</span><div><div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="2I81DVIUSW" ></input><label For="2I81DVIUSW">[0]</label><span Class="cw_vdom_hyr_type">traj1.environments.launcher_v1.launcher_v1.Stage:</span><div><div><div Class="cw_vdom_hyr cw_vdom_hyr_item"><style>.cw_vdom_hyr {
#     font-family: monospace;
# }
#
# .cw_vdom_hyr_item > input {
#     display: none;
# }
#
# .cw_vdom_hyr_item > label {
#     color: var(--jp-accent-color1);
#     font-weight: bold;
# }
#
# .cw_vdom_hyr_item > label::before {
#     content: "\00a0";
# }
#
# .cw_vdom_hyr_item > label::after {
#     content: ": ";
# }
#
# .cw_vdom_hyr_item > div {
#     display: inline-block;
# }
#
# .cw_vdom_hyr_item > input + label {
#     cursor: pointer;
# }
#
# .cw_vdom_hyr_item > input + label::before {
#     content: "+";
# }
#
# .cw_vdom_hyr_item > input:checked + label::before {
#     content: "-";
# }
#
# .cw_vdom_hyr_item > input ~ div {
#     display: none;
#     padding-left: 20px;
# }
#
# .cw_vdom_hyr_item > input:checked ~ div {
#     display: block;
# }
#
# .cw_vdom_hyr_type {
#     color: var(--jp-ui-font-color3);
#     font-size: var(--jp-ui-font-size0);
# }
# </style><input type="checkbox" id="PHGA7CFI54" checked></input><label For="PHGA7CFI54">Stage</label><span Class="cw_vdom_hyr_type">traj1.environments.launcher_v1.launcher_v1.Stage:</span><div><div><div Class="cw_vdom_hyr_item"><label For="H5V8W5XKTI">dry_mass</label><span Class="cw_vdom_hyr_type">int:</span><div><span>2150</span></div></div><div Class="cw_vdom_hyr_item"><label For="XAZVCXDZEF">propellant_mass</label><span Class="cw_vdom_hyr_type">int:</span><div><span>2353</span></div></div><div Class="cw_vdom_hyr_item"><label For="EZ40OW8VHD">specific_impulse</label><span Class="cw_vdom_hyr_type">int:</span><div><span>311</span></div></div><div Class="cw_vdom_hyr_item"><label For="KKP0UMHTIN">thrust</label><span Class="cw_vdom_hyr_type">int:</span><div><span>16000</span></div></div><div Class="cw_vdom_hyr_item"><label For="DEN4EIJAE9">n_ignitions</label><span Class="cw_vdom_hyr_type">int:</span><div><span>1</span></div></div><div Class="cw_vdom_hyr_item"><label For="JQS8NIIUOZ">burn_time</label><span Class="cw_vdom_hyr_type">float:</span><div><span>448.67445187500005</span></div></div></div></div></div></div></div></div></div></div></div><div Class="cw_vdom_hyr_item"><label For="XCF8G1K6J0">initial_altitude</label><span Class="cw_vdom_hyr_type">int:</span><div><span>1</span></div></div><div Class="cw_vdom_hyr_item"><label For="W2F2DUSBDX">initial_theta_e</label><span Class="cw_vdom_hyr_type">float:</span><div><span>1.5707963267948966</span></div></div><div Class="cw_vdom_hyr_item"><label For="TONUAKPGJF">initial_longitude</label><span Class="cw_vdom_hyr_type">float:</span><div><span>1.5707963267948966</span></div></div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="MVPKL5MILH" ></input><label For="MVPKL5MILH">initial_vie</label><span Class="cw_vdom_hyr_type">tuple[2]:</span><div><div><div Class="cw_vdom_hyr_item"><label For="2H7UO51OSN">[0]</label><span Class="cw_vdom_hyr_type">float:</span><div><span>0.0</span></div></div><div Class="cw_vdom_hyr_item"><label For="E610ED5PW5">[1]</label><span Class="cw_vdom_hyr_type">float:</span><div><span>0.0</span></div></div></div></div></div><div Class="cw_vdom_hyr_item"><label For="AQ9KA9BYUJ">initial_kepler</label><span Class="cw_vdom_hyr_type">NoneType:</span><div><span>None</span></div></div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="KCLJQOKGBX" ></input><label For="KCLJQOKGBX">gamma_controller_gains</label><span Class="cw_vdom_hyr_type">tuple[3]:</span><div><div><div Class="cw_vdom_hyr_item"><label For="GJYHY3M1OS">[0]</label><span Class="cw_vdom_hyr_type">int:</span><div><span>4</span></div></div><div Class="cw_vdom_hyr_item"><label For="BA4I25PVEF">[1]</label><span Class="cw_vdom_hyr_type">int:</span><div><span>0</span></div></div><div Class="cw_vdom_hyr_item"><label For="IZGV7NLF6G">[2]</label><span Class="cw_vdom_hyr_type">float:</span><div><span>0.2</span></div></div></div></div></div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="7SNRQIS2MI" ></input><label For="7SNRQIS2MI">theta_controller_gains</label><span Class="cw_vdom_hyr_type">tuple[3]:</span><div><div><div Class="cw_vdom_hyr_item"><label For="DD6MZXJ8UQ">[0]</label><span Class="cw_vdom_hyr_type">int:</span><div><span>10</span></div></div><div Class="cw_vdom_hyr_item"><label For="OIQI1ZILKN">[1]</label><span Class="cw_vdom_hyr_type">int:</span><div><span>0</span></div></div><div Class="cw_vdom_hyr_item"><label For="0BDUNF1UBY">[2]</label><span Class="cw_vdom_hyr_type">float:</span><div><span>0.0</span></div></div></div></div></div><div Class="cw_vdom_hyr_item"><input type="checkbox" id="DD6996GZ98" ></input><label For="DD6996GZ98">controller_theta_dot_limits</label><span Class="cw_vdom_hyr_type">tuple[2]:</span><div><div><div Class="cw_vdom_hyr_item"><label For="80PWMUXS3M">[0]</label><span Class="cw_vdom_hyr_type">int:</span><div><span>-1</span></div></div><div Class="cw_vdom_hyr_item"><label For="3FWHCC4PHB">[1]</label><span Class="cw_vdom_hyr_type">int:</span><div><span>1</span></div ...

# %%
case_runner = CaseRunner(
    env=env,
    max_time=1000
)

# %%
# x = [
#     200., 400., 645.,
#     0., 200., 400, 1500,
#     radians(90.), radians(45.), radians(0.), radians(0.),
# ]

x = [
    200., 400., 650.,
    200., 400,
    radians(90.), radians(45.), radians(0.), radians(0.),
]

case_runner(x)
# Out:
# [200.0, 400.0, 650.0] 4 (0, 200.0, 400, 1000) [1.5707963267948966, 0.7853981633974483, 0.0, 0.0]
# 0.059224065049747913 [200.0, 400.0, 650.0, 200.0, 400, 1.5707963267948966, 0.7853981633974483, 0.0, 0.0]
# 0.059224065049747913

# %%
plotter = Plotter(env, case_runner.last_result)

# %%
plotter.orbit_view();
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plotter.alt();
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plotter.orbital_elements();
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Optimize

# %%
x = [
    200., 400., 650.,
    0., 200., 400, 1500,
    radians(90.), radians(45.), radians(0.), radians(0.),
]

res = minimize(case_runner, x)
res
# Out:
# 0.059684020974302664 [2.00000000e+02 4.00000000e+02 6.50000000e+02 0.00000000e+00
#  2.00000000e+02 4.00000000e+02 1.50000000e+03 1.57079633e+00
#  7.85398163e-01 0.00000000e+00 0.00000000e+00]
#   1.99998944e+02  4.00000040e+02  1.49999980e+03  1.57673849e+00
#   7.85532768e-01  7.40630896e-03  1.26817281e-02]
# 0.10010119911422524 [ 2.00013051e+02  4.00001856e+02  6.50003776e+02 -1.59539851e-03
#   1.99998944e+02  4.00000040e+02  1.49999980e+03  1.57673849e+00
#   7.85532768e-01  7.40630896e-03  1.26817281e-02]
# 0.10665342920311066 [ 2.00013051e+02  4.00001856e+02  6.50003776e+02 -1.59539851e-03
#   1.99998944e+02  4.00000040e+02  1.49999980e+03  1.57673849e+00
#   7.85532768e-01  7.40630896e-03  1.26817281e-02]
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3397, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_40763/352586455.py", line 7, in <cell line: 7>
#     res = minimize(case_runner, x)
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/optimize/_minimize.py", line 618, in minimize
#     return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/optimize/optimize.py", line 1235, in _minimize_bfgs
#     _line_search_wolfe12(f, myfprime, xk, pk, gfk,
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/optimize/optimize.py", line 1005, in _line_search_wolfe12
#     ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/optimize/linesearch.py", line 96, in line_search_wolfe1
#     stp, fval, old_fval = scalar_search_wolfe1(
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/optimize/linesearch.py", line 173, in scalar_search_wolfe1
#     derphi1 = derphi(stp)
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/optimize/linesearch.py", line 87, in derphi
#     gval[0] = fprime(xk + s*pk, *newargs)
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py", line 255, in grad
#     self._update_grad()
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py", line 238, in _update_grad
#     self._update_grad_impl()
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py", line 155, in update_grad
#     self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/optimize/_numdiff.py", line 486, in approx_derivative
#     return _dense_difference(fun_wrapped, x0, f0, h,
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/optimize/_numdiff.py", line 557, in _dense_difference
#     df = fun(x) - f0
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/optimize/_numdiff.py", line 437, in fun_wrapped
#     f = np.atleast_1d(fun(x, *args, **kwargs))
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py", line 134, in fun_wrapped
#     return fun(np.copy(x), *args)
#   File "/home/adewindt/repos/thesis/code/trajectory_optimization_1/work/to_orbital/case_runner.py", line 37, in __call__
#     result = self.run_case_interpolation(engine_timing, times, pitches)
#   File "/home/adewindt/repos/thesis/code/trajectory_optimization_1/work/to_orbital/case_runner.py", line 53, in run_case_interpolation
#     pitch_angle = pitch_interpolator(time)
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/interpolate/polyint.py", line 78, in __call__
#     y = self._evaluate(x)
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/interpolate/interpolate.py", line 682, in _evaluate
#     y_new = self._call(self, x_new)
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/scipy/interpolate/interpolate.py", line 612, in _call_linear
#     x_new_indices = searchsorted(self.x, x_new)
#   File "<__array_function__ internals>", line 177, in searchsorted
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 1992, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#   File "/home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
