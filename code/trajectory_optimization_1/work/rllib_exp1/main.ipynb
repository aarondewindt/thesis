# %% [markdown]
# # RLLib experiment

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
from ray import tune
from ray.rllib.agents.ppo import PPOTrainer
tune.run(PPOTrainer, config={"env": "CartPole-v0"})
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2021-05-08 00:01:15,233	INFO services.py:1267 -- View the Ray dashboard at http://127.0.0.1:8265
# == Status ==<br>Memory usage on this node: 11.5/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/1 GPUs, 0.0/8.81 GiB heap, 0.0/4.41 GiB objects (0.0/1.0 accelerator_type:K1100M)<br>Result logdir: /home/jovyan/ray_results/PPO_2021-05-08_00-01-17<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v0_82f20_00000</td><td>RUNNING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (pid=626) WARNING:tensorflow:From /opt/conda/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=626) Instructions for updating:
# (pid=626) non-resource variables are not supported in the long term
# (pid=626) 2021-05-08 00:01:19,808	INFO trainer.py:669 -- Tip: set framework=tfe or the --eager flag to enable TensorFlow eager execution
# (pid=626) 2021-05-08 00:01:19,808	INFO trainer.py:694 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=628) WARNING:tensorflow:From /opt/conda/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=628) Instructions for updating:
# (pid=628) non-resource variables are not supported in the long term
# (pid=622) WARNING:tensorflow:From /opt/conda/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=622) Instructions for updating:
# (pid=622) non-resource variables are not supported in the long term
# (pid=626) 2021-05-08 00:01:24,362	WARNING util.py:53 -- Install gputil for GPU system monitoring.
# (pid=626) 2021-05-08 00:01:26,275	WARNING deprecation.py:33 -- DeprecationWarning: `SampleBatch.data[..]` has been deprecated. Use `SampleBatch[..]` instead. This will raise an error in the future!
# Result for PPO_CartPole-v0_82f20_00000:
#   agent_timesteps_total: 4000
#   custom_metrics: {}
#   date: 2021-05-08_00-01-29
#   done: false
#   episode_len_mean: 22.75862068965517
#   episode_media: {}
#   episode_reward_max: 64.0
#   episode_reward_mean: 22.75862068965517
#   episode_reward_min: 9.0
#   episodes_this_iter: 174
#   episodes_total: 174
#   experiment_id: 37bf88f6a561405a93a2c3a0f9a0ace3
#   hostname: f4ec6381fa5f
#   info:
#     learner:
#       default_policy:
#         learner_stats:
#           cur_kl_coeff: 0.20000000298023224
#           cur_lr: 4.999999873689376e-05
#           entropy: 0.6632022857666016
#           entropy_coeff: 0.0
#           kl: 0.031432487070560455
#           model: {}
#           policy_loss: -0.0421614944934845
#           total_loss: 89.09925842285156
#           vf_explained_var: 0.09817507863044739
#           vf_loss: 89.1351318359375
#     num_agent_steps_sampled: 4000
#     num_steps_sampled: 4000
#     num_steps_trained: 4000
#   iterations_since_restore: 1
#   node_ip: 10.10.3.2
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 47.0
#     ram_util_percent: 77.95
#   pid: 626
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05349450428929996
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.07387152273459492
#     mean_inference_ms: 0.6886050111514614
#     mean_raw_obs_processing_ms: 0.09617008300888884
#   time_since_restore: 5.486731052398682
#   time_this_iter_s: 5.486731052398682
#   time_total_s: 5.486731052398682
#   timers:
#     learn_throughput: 1126.561
#     learn_time_ms: 3550.63
#     sample_throughput: 2129.64
#     sample_time_ms: 1878.251
#     update_time_ms: 2.727
#   timestamp: 1620432089
#   timesteps_since_restore: 0
#   timesteps_total: 4000
#   training_iteration: 1
#   trial_id: 82f20_00000
# == Status ==<br>Memory usage on this node: 12.1/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/1 GPUs, 0.0/8.81 GiB heap, 0.0/4.41 GiB objects (0.0/1.0 accelerator_type:K1100M)<br>Result logdir: /home/jovyan/ray_results/PPO_2021-05-08_00-01-17<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc          </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v0_82f20_00000</td><td>RUNNING </td><td>10.10.3.2:626</td><td style="text-align: right;">     1</td><td style="text-align: right;">         5.48673</td><td style="text-align: right;">4000</td><td style="text-align: right;"> 22.7586</td><td style="text-align: right;">                  64</td><td style="text-align: right;">                   9</td><td style="text-align: right;">           22.7586</td></tr>
# </tbody>
# </table><br><br>
# Result for PPO_CartPole-v0_82f20_00000:
#   agent_timesteps_total: 8000
#   custom_metrics: {}
#   date: 2021-05-08_00-01-35
#   done: false
#   episode_len_mean: 45.21
#   episode_media: {}
#   episode_reward_max: 151.0
#   episode_reward_mean: 45.21
#   episode_reward_min: 9.0
#   episodes_this_iter: 76
#   episodes_total: 250
#   experiment_id: 37bf88f6a561405a93a2c3a0f9a0ace3
#   hostname: f4ec6381fa5f
#   info:
#     learner:
#       default_policy:
#         learner_stats:
#           cur_kl_coeff: 0.30000001192092896
#           cur_lr: 4.999999873689376e-05
#           entropy: 0.610129714012146
#           entropy_coeff: 0.0
#           kl: 0.018883833661675453
#           model: {}
#           policy_loss: -0.019789934158325195
#           total_loss: 312.0869445800781
#           vf_explained_var: 0.08440161496400833
#           vf_loss: 312.10107421875
#     num_agent_steps_sampled: 8000
#     num_steps_sampled: 8000
#     num_steps_trained: 8000
#   iterations_since_restore: 2
#   node_ip: 10.10.3.2
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 49.0625
#     ram_util_percent: 78.025
#   pid: 626
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05478797953403856
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.07466013411991664
#     mean_inference_ms: 0.7005886472506859
#     mean_raw_obs_processing_ms: 0.09339091044291034
#   time_since_restore: 11.061628580093384
#   time_this_iter_s: 5.574897527694702
#   time_total_s: 11.061628580093384
#   timers:
#     learn_throughput: 1119.469
#     learn_time_ms: 3573.123
#     sample_throughput: 2101.801
#     sample_time_ms: 1903.13
#     update_time_ms: 2.773
#   timestamp: 1620432095
#   timesteps_since_restore: 0
#   timesteps_total: 8000
#   training_iteration: 2
#   trial_id: 82f20_00000
# == Status ==<br>Memory usage on this node: 12.1/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/1 GPUs, 0.0/8.81 GiB heap, 0.0/4.41 GiB objects (0.0/1.0 accelerator_type:K1100M)<br>Result logdir: /home/jovyan/ray_results/PPO_2021-05-08_00-01-17<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc          </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v0_82f20_00000</td><td>RUNNING </td><td>10.10.3.2:626</td><td style="text-align: right;">     2</td><td style="text-align: right;">         11.0616</td><td style="text-align: right;">8000</td><td style="text-align: right;">   45.21</td><td style="text-align: right;">                 151</td><td style="text-align: right;">                   9</td><td style="text-align: right;">             45.21</td></tr>
# </tbody>
# </table><br><br>
# Result for PPO_CartPole-v0_82f20_00000:
#   agent_timesteps_total: 12000
#   custom_metrics: {}
#   date: 2021-05-08_00-01-41
#   done: false
#   episode_len_mean: 75.37
#   episode_media: {}
#   episode_reward_max: 200.0
#   episode_reward_mean: 75.37
#   episode_reward_min: 10.0
#   episodes_this_iter: 31
#   episodes_total: 281
#   experiment_id: 37bf88f6a561405a93a2c3a0f9a0ace3
#   hostname: f4ec6381fa5f
#   info:
#     learner:
#       default_policy:
#         learner_stats:
#           cur_kl_coeff: 0.30000001192092896
#           cur_lr: 4.999999873689376e-05
#           entropy: 0.5644036531448364
#           entropy_coeff: 0.0
#           kl: 0.009609872475266457
#           model: {}
#           policy_loss: -0.018594417721033096
#           total_loss: 698.6914672851562
#           vf_explained_var: 0.10754731297492981
#           vf_loss: 698.7071533203125
#     num_agent_steps_sampled: 12000
#     num_steps_sampled: 12000
#     num_steps_trained: 12000
#   iterations_since_restore: 3
#   node_ip: 10.10.3.2
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 47.3625
#     ram_util_percent: 77.9625
#   pid: 626
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05508380740478076
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.07553763006223253
#     mean_inference_ms: 0.7078669282034695
#     mean_raw_obs_processing_ms: 0.09172057311742451
#   time_since_restore: 16.550938844680786
#   time_this_iter_s: 5.489310264587402
#   time_total_s: 16.550938844680786
#   timers:
#     learn_throughput: 1130.697
#     learn_time_ms: 3537.64
#     sample_throughput: 2076.234
#     sample_time_ms: 1926.565
#     update_time_ms: 2.661
#   timestamp: 1620432101
#   timesteps_since_restore: 0
#   timesteps_total: 12000
#   training_iteration: 3
#   trial_id: 82f20_00000
# == Status ==<br>Memory usage on this node: 12.1/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/1 GPUs, 0.0/8.81 GiB heap, 0.0/4.41 GiB objects (0.0/1.0 accelerator_type:K1100M)<br>Result logdir: /home/jovyan/ray_results/PPO_2021-05-08_00-01-17<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc          </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v0_82f20_00000</td><td>RUNNING </td><td>10.10.3.2:626</td><td style="text-align: right;">     3</td><td style="text-align: right;">         16.5509</td><td style="text-align: right;">12000</td><td style="text-align: right;">   75.37</td><td style="text-align: right;">                 200</td><td style="text-align: right;">                  10</td><td style="text-align: right;">             75.37</td></tr>
# </tbody>
# </table><br><br>
# Result for PPO_CartPole-v0_82f20_00000:
#   agent_timesteps_total: 16000
#   custom_metrics: {}
#   date: 2021-05-08_00-01-46
#   done: false
#   episode_len_mean: 102.56
#   episode_media: {}
#   episode_reward_max: 200.0
#   episode_reward_mean: 102.56
#   episode_reward_min: 10.0
#   episodes_this_iter: 23
#   episodes_total: 304
#   experiment_id: 37bf88f6a561405a93a2c3a0f9a0ace3
#   hostname: f4ec6381fa5f
#   info:
#     learner:
#       default_policy:
#         learner_stats:
#           cur_kl_coeff: 0.30000001192092896
#           cur_lr: 4.999999873689376e-05
#           entropy: 0.5520140528678894
#           entropy_coeff: 0.0
#           kl: 0.0032676830887794495
#           model: {}
#           policy_loss: -0.007909215986728668
#           total_loss: 533.814453125
#           vf_explained_var: 0.3278636038303375
#           vf_loss: 533.8213500976562
#     num_agent_steps_sampled: 16000
#     num_steps_sampled: 16000
#     num_steps_trained: 16000
#   iterations_since_restore: 4
#   node_ip: 10.10.3.2
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 49.3125
#     ram_util_percent: 77.9375
#   pid: 626
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05592258858339573
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.07570637458398723
#     mean_inference_ms: 0.7115812560195448
#     mean_raw_obs_processing_ms: 0.09102772757554453
#   time_since_restore: 22.217787504196167
#   time_this_iter_s: 5.666848659515381
#   time_total_s: 22.217787504196167
#   timers:
#     learn_throughput: 1124.564
#     learn_time_ms: 3556.935
#     sample_throughput: 2060.907
#     sample_time_ms: 1940.893
#     update_time_ms: 2.688
#   timestamp: 1620432106
#   timesteps_since_restore: 0
#   timesteps_total: 16000
#   training_iteration: 4
#   trial_id: 82f20_00000
# == Status ==<br>Memory usage on this node: 12.1/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/1 GPUs, 0.0/8.81 GiB heap, 0.0/4.41 GiB objects (0.0/1.0 accelerator_type:K1100M)<br>Result logdir: /home/jovyan/ray_results/PPO_2021-05-08_00-01-17<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc          </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v0_82f20_00000</td><td>RUNNING </td><td>10.10.3.2:626</td><td style="text-align: right;">     4</td><td style="text-align: right;">         22.2178</td><td style="text-align: right;">16000</td><td style="text-align: right;">  102.56</td><td style="text-align: right;">                 200</td><td style="text-align: right;">                  10</td><td style="text-align: right;">            102.56</td></tr>
# </tbody>
# </table><br><br>
# Result for PPO_CartPole-v0_82f20_00000:
#   agent_timesteps_total: 20000
#   custom_metrics: {}
#   date: 2021-05-08_00-01-52
#   done: false
#   episode_len_mean: 130.93
#   episode_media: {}
#   episode_reward_max: 200.0
#   episode_reward_mean: 130.93
#   episode_reward_min: 12.0
#   episodes_this_iter: 22
#   episodes_total: 326
#   experiment_id: 37bf88f6a561405a93a2c3a0f9a0ace3
#   hostname: f4ec6381fa5f
#   info:
#     learner:
#       default_policy:
#         learner_stats:
#           cur_kl_coeff: 0.15000000596046448
#           cur_lr: 4.999999873689376e-05
#           entropy: 0.5262472629547119
#           entropy_coeff: 0.0
#           kl: 0.005115798208862543
#           model: {}
#           policy_loss: -0.0035153208300471306
#           total_loss: 401.8382873535156
#           vf_explained_var: 0.34212303161621094
#           vf_loss: 401.8410339355469
#     num_agent_steps_sampled: 20000
#     num_steps_sampled: 20000
#     num_steps_trained: 20000
#   iterations_since_restore: 5
#   node_ip: 10.10.3.2
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 54.74444444444444
#     ram_util_percent: 77.93333333333334
#   pid: 626
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.056849037108345504
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.07688562152329896
#     mean_inference_ms: 0.7223837945273296
#     mean_raw_obs_processing_ms: 0.09063828862314866
#   time_since_restore: 28.472843647003174
#   time_this_iter_s: 6.255056142807007
#   time_total_s: 28.472843647003174
#   timers:
#     learn_throughput: 1106.062
#     learn_time_ms: 3616.434
#     sample_throughput: 1979.003
#     sample_time_ms: 2021.22
#     update_time_ms: 2.608
#   timestamp: 1620432112
#   timesteps_since_restore: 0
#   timesteps_total: 20000
#   training_iteration: 5
#   trial_id: 82f20_00000
# == Status ==<br>Memory usage on this node: 12.1/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/1 GPUs, 0.0/8.81 GiB heap, 0.0/4.41 GiB objects (0.0/1.0 accelerator_type:K1100M)<br>Result logdir: /home/jovyan/ray_results/PPO_2021-05-08_00-01-17<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc          </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v0_82f20_00000</td><td>RUNNING </td><td>10.10.3.2:626</td><td style="text-align: right;">     5</td><td style="text-align: right;">         28.4728</td><td style="text-align: right;">20000</td><td style="text-align: right;">  130.93</td><td style="text-align: right;">                 200</td><td style="text-align: right;">                  12</td><td style="text-align: right;">            130.93</td></tr>
# </tbody>
# </table><br><br>
# Result for PPO_CartPole-v0_82f20_00000:
#   agent_timesteps_total: 24000
#   custom_metrics: {}
#   date: 2021-05-08_00-01-58
#   done: false
#   episode_len_mean: 159.66
#   episode_media: {}
#   episode_reward_max: 200.0
#   episode_reward_mean: 159.66
#   episode_reward_min: 13.0
#   episodes_this_iter: 21
#   episodes_total: 347
#   experiment_id: 37bf88f6a561405a93a2c3a0f9a0ace3
#   hostname: f4ec6381fa5f
#   info:
#     learner:
#       default_policy:
#         learner_stats:
#           cur_kl_coeff: 0.15000000596046448
#           cur_lr: 4.999999873689376e-05
#           entropy: 0.5254348516464233
#           entropy_coeff: 0.0
#           kl: 0.007908632978796959
#           model: {}
#           policy_loss: 0.0021132873371243477
#           total_loss: 223.21881103515625
#           vf_explained_var: 0.5903816223144531
#           vf_loss: 223.2154998779297
#     num_agent_steps_sampled: 24000
#     num_steps_sampled: 24000
#     num_steps_trained: 24000
#   iterations_since_restore: 6
#   node_ip: 10.10.3.2
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 52.28888888888889
#     ram_util_percent: 77.9
#   pid: 626
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05765137026003571
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.07848978152167861
#     mean_inference_ms: 0.7357938690496592
#     mean_raw_obs_processing_ms: 0.0901851944995087
#   time_since_restore: 34.39423727989197
#   time_this_iter_s: 5.921393632888794
#   time_total_s: 34.39423727989197
#   timers:
#     learn_throughput: 1103.613
#     learn_time_ms: 3624.459
#     sample_throughput: 1949.047
#     sample_time_ms: 2052.285
#     update_time_ms: 2.617
#   timestamp: 1620432118
#   timesteps_since_restore: 0
#   timesteps_total: 24000
#   training_iteration: 6
#   trial_id: 82f20_00000
# == Status ==<br>Memory usage on this node: 12.1/15.6 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3.0/8 CPUs, 0/1 GPUs, 0.0/8.81 GiB heap, 0.0/4.41 GiB objects (0.0/1.0 accelerator_type:K1100M)<br>Result logdir: /home/jovyan/ray_results/PPO_2021-05-08_00-01-17<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc          </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v0_82f20_00000</td><td>RUNNING </td><td>10.10.3.2:626</td><td style="text-align: right;">     6</td><td style="text-align: right;">         34.3942</td><td style="text-align: right;">24000</td><td style="text-align: right;">  159.66</td><td style="text-align: right;">                 200</td><td style="text-align: right;">                  13</td><td style="text-align: right;">            159.66</td></tr>
# </tbody>
# </table><br><br>
# 2021-05-08 00:02:00,988	WARNING tune.py:506 -- SIGINT received (e.g. via Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C one more time (or send SIGINT/SIGKILL/SIGTERM) to skip.
