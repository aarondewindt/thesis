# %% [markdown]
# # Initialize learning environment

# %%
import ray
from cw.vdom import hyr

# %%
hyr(ray.init(dashboard_host="0.0.0.0"))
# Out:
# 2022-05-09 03:26:17,536	INFO services.py:1456 -- View the Ray dashboard at http://192.168.0.100:8265
# /home/adewindt/miniconda3/envs/traj1/lib/python3.9/site-packages/ray/worker.py:650: UserWarning: len(ctx) is deprecated. Use len(ctx.address_info) instead.
#   warnings.warn("len(ctx) is deprecated. Use len(ctx.address_info) instead.")
# ray.worker.RayContext[11]:
#
# []str[15]:
#
# node_ip_address
#
# []str[17]:
#
# raylet_ip_address
#
# []str[13]:
#
# redis_address
#
# []str[20]:
#
# object_store_address
#
# []str[18]:
#
# raylet_socket_name
#
# []str[9]:
#
# webui_url
#
# []str[11]:
#
# session_dir
#
# []str[19]:
#
# metrics_export_port
#
# []str[11]:
#
# gcs_address
#
# []str[7]:
#
# address
#
# []str[7]:
#
# node_id

# %%
ray.shutdown()

# %%
# !tensorboard --logdir=./results --port=8270 --host=0.0.0.0
# Out:
# TensorBoard 2.4.1 at http://0.0.0.0:8270/ (Press CTRL+C to quit)
