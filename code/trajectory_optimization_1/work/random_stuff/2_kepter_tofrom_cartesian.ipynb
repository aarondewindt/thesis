# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
import numpy as np

from cw.astrodynamics import cartesian_to_kepler, cartesian_to_kepler_no_anomalies, cartesian_to_kepler_no_anomalies_2d

# %%
example_data = [
    {
        "cartesian": ([-2700816.14, -3314092.80, 5266346.42], [5168.606550, -5597.546618, -868.878445]),
        "kepler": (6787746.891, 0.000731104,
                   *np.radians((51.68714486, 127.5486706, 74.21987137, 24.10027677, 24.08317766, 24.06608426)))
    },
    {
        "cartesian": ([3126974.99, -6374445.74, 28673.59], [-254.91197, -83.30107, 7485.70674]),
        "kepler": (7096137.00, 0.0011219,
                   *np.radians((92.0316, 296.1384, 120.6878, 239.5437, 239.5991, 239.6546)))
    }
]

# %%
# %timeit cartesian_to_kepler([-2700816.14, -3314092.80, 5266346.42], [5168.606550, -5597.546618, -868.878445])
# Out:
# 344 µs ± 4.48 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit cartesian_to_kepler_no_anomalies(np.array([-2700816.14, -3314092.80, 5266346.42]), np.array([5168.606550, -5597.546618, -868.878445]))
# Out:
# 6.16 µs ± 100 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
cartesian_to_kepler_no_anomalies_2d(np.array([-2700816.14, -3314092.80]), np.array([0., 0.]))
# Out:
# (2137616.5996908997, 1.0)

# %%
# Out:
# 6783216.311200989
